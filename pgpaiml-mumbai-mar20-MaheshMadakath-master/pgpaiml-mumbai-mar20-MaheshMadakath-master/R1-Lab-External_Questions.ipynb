# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
from pandas import DataFrame, Series
Iris = pd.read_csv("iris.csv", sep=',')
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
print(Iris.head(10))
print(Iris.tail(10))
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
Iris = Iris.reindex(['Index','Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
       'Petal width (in cm)', 'Class'],axis =1)
Iris['Index'] = range(0,150,1)
Iris.head()
# Out:
#    Index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0      0                   5.1                  3.5                   1.4
# 1      1                   4.9                  3.0                   1.4
# 2      2                   4.7                  3.2                   1.3
# 3      3                   4.6                  3.1                   1.5
# 4      4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,3:4]
# Out:
#      Petal length (in cm)
# 0                     1.4
# 1                     1.4
# 2                     1.3
# 3                     1.5
# 4                     1.4
# ..                    ...
# 145                   5.2
# 146                   5.0
# 147                   5.2
# 148                   5.4
# 149                   5.1
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.iloc[:11,1:3]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)
# 0                    5.1                  3.5
# 1                    4.9                  3.0
# 2                    4.7                  3.2
# 3                    4.6                  3.1
# 4                    5.0                  3.6
# 5                    5.4                  3.9
# 6                    4.6                  3.4
# 7                    5.0                  3.4
# 8                    4.4                  2.9
# 9                    4.9                  3.1
# 10                   5.4                  3.7

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[(Iris['Class'] =="Iris-setosa")]
# Out:
#     Index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0       0                   5.1                  3.5                   1.4
# 1       1                   4.9                  3.0                   1.4
# 2       2                   4.7                  3.2                   1.3
# 3       3                   4.6                  3.1                   1.5
# 4       4                   5.0                  3.6                   1.4
# 5       5                   5.4                  3.9                   1.7
# 6       6                   4.6                  3.4                   1.4
# 7       7                   5.0                  3.4                   1.5
# 8       8                   4.4                  2.9                   1.4
# 9       9                   4.9                  3.1                   1.5
# 10     10                   5.4                  3.7                   1.5
# 11     11                   4.8                  3.4                   1.6
# 12     12                   4.8                  3.0                   1.4
# 13     13                   4.3                  3.0                   1.1
# 14     14                   5.8                  4.0                   1.2
# 15     15                   5.7                  4.4                   1.5
# 16     16                   5.4                  3.9                   1.3
# 17     17                   5.1                  3.5                   1.4
# 18     18                   5.7                  3.8                   1.7
# 19     19                   5.1                  3.8                   1.5
# 20     20                   5.4                  3.4                   1.7
# 21     21                   5.1                  3.7                   1.5
# 22     22                   4.6                  3.6                   1.0
# 23     23                   5.1                  3.3                   1.7
# 24     24                   4.8                  3.4                   1.9
# 25     25                   5.0                  3.0                   1.6
# 26     26                   5.0                  3.4                   1.6
# 27     27                   5.2                  3.5                   1.5
# 28     28                   5.2                  3.4                   1.4
# 29     29                   4.7                  3.2                   1.6
# 30     30                   4.8                  3.1                   1.6
# 31     31                   5.4                  3.4                   1.5
# 32     32                   5.2                  4.1                   1.5
# 33     33                   5.5                  4.2                   1.4
# 34     34                   4.9                  3.1                   1.5
# 35     35                   5.0                  3.2                   1.2
# 36     36                   5.5                  3.5                   1.3
# 37     37                   4.9                  3.1                   1.5
# 38     38                   4.4                  3.0                   1.3
# 39     39                   5.1                  3.4                   1.5
# 40     40                   5.0                  3.5                   1.3
# 41     41                   4.5                  2.3                   1.3
# 42     42                   4.4                  3.2                   1.3
# 43     43                   5.0                  3.5                   1.6
# 44     44                   5.1                  3.8                   1.9
# 45     45                   4.8                  3.0                   1.4
# 46     46                   5.1                  3.8                   1.6
# 47     47                   4.6                  3.2                   1.4
# 48     48                   5.3                  3.7                   1.5
# 49     49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)']*Iris['Sepal Width in (cm)']
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %%
Iris[(Iris['Class'] == "Iris-virginica")].var(axis=0)
# Out:
# Index                   212.500000
# Sepal Length (in cm)      0.404343
# Sepal Width in (cm)       0.104004
# Petal length (in cm)      0.304588
# Petal width (in cm)       0.075433
# SepalExtra               11.963180
# dtype: float64

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Mean = DataFrame({'Mean':('Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
       'Petal width (in cm)'),
                     'Iris-virginica':Iris[Iris['Class'] == "Iris-virginica"].iloc[:,1:5].mean(axis=0).values, 
                     'Iris-setosa':Iris[Iris['Class'] == "Iris-setosa"].iloc[:,1:5].mean(axis=0).values,  
                     'Iris-versicolor':Iris[Iris['Class'] == "Iris-versicolor"].iloc[:,1:5].mean(axis=0).values})
Var = DataFrame({'Variance':('Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
       'Petal width (in cm)'),
                     'Iris-virginica':Iris[Iris['Class'] == "Iris-virginica"].iloc[:,1:5].var(axis=0).values, 
                     'Iris-setosa':Iris[Iris['Class'] == "Iris-setosa"].iloc[:,1:5].var(axis=0).values,  
                     'Iris-versicolor':Iris[Iris['Class'] == "Iris-versicolor"].iloc[:,1:5].var(axis=0).values})
print(Mean)
print(Var)
# Out:
#                    Mean  Iris-virginica  Iris-setosa  Iris-versicolor
# 0  Sepal Length (in cm)           6.588        5.006            5.936
# 1   Sepal Width in (cm)           2.974        3.418            2.770
# 2  Petal length (in cm)           5.552        1.464            4.260
# 3   Petal width (in cm)           2.026        0.244            1.326
#                Variance  Iris-virginica  Iris-setosa  Iris-versicolor
# 0  Sepal Length (in cm)        0.404343     0.124249         0.266433
# 1   Sepal Width in (cm)        0.104004     0.145180         0.098469
# 2  Petal length (in cm)        0.304588     0.030106         0.220816
# 3   Petal width (in cm)        0.075433     0.011494         0.039106

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def display(a,b):
    return(print("First Number", a, "and Second Number", b))
display(Iris.iloc[4,1],Iris.iloc[4,2])
# Out:
# First Number 5.0 and Second Number 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
SLengthRange = Iris['Sepal Length (in cm)'].max()-Iris['Sepal Length (in cm)'].min()
SWidthRange = Iris['Sepal Width in (cm)'].max()-Iris['Sepal Width in (cm)'].min()
PLengthRange = Iris['Petal length (in cm)'].max()-Iris['Petal length (in cm)'].min()
PWidthRange = Iris['Petal width (in cm)'].max()-Iris['Petal width (in cm)'].min()
print ('Sepal Length Range: ',round(SLengthRange,1), "\n",'Sepal Width Range: ',round(SWidthRange,1), "\n",
       'Petal Length Range: ',PLengthRange, "\n",'Petal Width Range: ',PWidthRange)
# Out:
# Sepal Length Range:  3.6
#  Sepal Width Range:  2.4
#  Petal Length Range:  5.9
#  Petal Width Range:  2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values('Petal width (in cm)')
# Out:
#      Index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32      32                   5.2                  4.1                   1.5
# 13      13                   4.3                  3.0                   1.1
# 37      37                   4.9                  3.1                   1.5
# 9        9                   4.9                  3.1                   1.5
# 12      12                   4.8                  3.0                   1.4
# ..     ...                   ...                  ...                   ...
# 140    140                   6.7                  3.1                   5.6
# 114    114                   5.8                  2.8                   5.1
# 100    100                   6.3                  3.3                   6.0
# 144    144                   6.7                  3.3                   5.7
# 109    109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra
# 32                   0.1     Iris-setosa       21.32
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
# 12                   0.1     Iris-setosa       14.40
# ..                   ...             ...         ...
# 140                  2.4  Iris-virginica       20.77
# 114                  2.4  Iris-virginica       16.24
# 100                  2.5  Iris-virginica       20.79
# 144                  2.5  Iris-virginica       22.11
# 109                  2.5  Iris-virginica       25.92
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris = Iris.drop('SepalExtra',axis =1)
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR = pd.read_csv("HR.txt",sep='\t',header=0)
HR.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
print('No of Rows in the dataset:' , HR.shape[0])
# Out:
# No of Rows in the dataset: 1470

# %%
print('No of Columns in the dataset:' , HR.shape[1])
# Out:
# No of Columns in the dataset: 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# ...              ...            ...
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
HRMale = HR[(HR['Gender'] == 1)] # Assuming 1 denotes for Male and 2 Denotes for Female 
HRFemale = HR[(HR['Gender'] == 2)]
print(' Number of Male Employees in the company  :' , HRMale['Gender'].count(), "\n",
      'Number of Female Employees in the company:' , HRFemale['Gender'].count())
# Out:
#  Number of Male Employees in the company  : 882
#  Number of Female Employees in the company: 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
print('IQR for the Age:' , HR['Age'].quantile(0.75)-HR['Age'].quantile(0.25))
# Out:
# IQR for the Age: 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print('Daily Rate : Mean = ', HR['DailyRate'].mean() ,
      ', Median = ', HR['DailyRate'].median(), 
      ', Variance = ', HR['DailyRate'].var())
# Out:
# Daily Rate : Mean =  802.4857142857143 , Median =  802.0 , Variance =  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
pd.crosstab(HR.Gender,HR.Attrition).plot(kind='bar')
plt.title('Attrition with respect to Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency of Attrition')
 # Assuming 1 denotes for Male and 2 Denotes for Female 
 # Inference-Attrition for Male employees is higher than that of Female employees
# Out:
# Text(0, 0.5, 'Frequency of Attrition')

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
HR.TotalWorkingYears.plot(kind = 'hist',bins = 10,figsize = (5,5),color = 'b')
plt.title('Frequency of working year bin in the company ')
plt.xlabel('Total Working Years')
# Inference-Right skewed with TotalWorkingYears highest in 5 to 10 Years
# Out:
# Text(0.5, 0, 'Total Working Years')
